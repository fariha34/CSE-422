# %% [markdown]
# <a href="https://colab.research.google.com/github/fariha34/CSE-422/blob/main/MinMax.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def calculate_score(path, goal, weights):
    return -sum(weights[i] * abs(ord(goal[i]) - ord(path[i])) for i in range(len(path)))

def min_max(path, pool, goal, weights, is_max_player, alpha, beta):
    if len(path) == len(goal):
        return path, calculate_score(path, goal, weights)

    if is_max_player:
        best_score = float('-inf')
        best_path = ""
        for i, char in enumerate(pool):
            new_pool = pool[:i] + pool[i+1:]
            p, s = min_max(path + char, new_pool, goal, weights, False, alpha, beta)
            if s > best_score:
                best_score = s
                best_path = p
            alpha = max(alpha, best_score)
            if alpha >= beta:  # Beta cut-off
                break
        return best_path, best_score
    else:
        best_score = float('inf')
        best_path = ""
        for i, char in enumerate(pool):
            new_pool = pool[:i] + pool[i+1:]
             # Make the recursive call for the maximizing player and get the path and score
            p, s =min_max(path + char, new_pool, goal, weights,True, alpha, beta)
            if s < best_score:
                best_score = s
                best_path = p
            beta = min(beta, best_score)
            if alpha >= beta:  # Beta cut-off
                break
        return best_path, best_score

            # TODO: Complete this section for the minimizing player
            # Hint: Use min(), update beta, and check alpha-beta condition
        return

pool = ['A','B','C','D']
goal = 'ABCD'
weights = [1, 1, 1, 1]

best_path, best_score = min_max("", pool, goal, weights, True, float('-inf'), float('inf'))
print(f"Best string generated: {best_path}")
print(f"Best score: {best_score}")
# Out:
# Best string generated: ADBC
# Best score: -4
