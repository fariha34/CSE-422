# %% [markdown]
# <a href="https://colab.research.google.com/github/fariha34/CSE-422/blob/main/Genetic_Algorithm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

cro1="000111000"
cro2="111000111"

a=2  # child point
b=4

offspring1= cro1[:a]+ cro2[a:b]+cro1[b:]
offspring2= cro2[:a]+ cro1[a:b]+cro2[b:]
print(f'parent:{cro1}')
print(f'parent:{cro2}')
print(f'child:{offspring1}')
print(f'child:{offspring2}')
# Out:
# parent:000111000
# parent:111000111
# child:001011000
# child:110100111
